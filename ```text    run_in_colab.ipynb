# %%
# Run the Bridge Slam Engine Benchmark
# %cd /content
# !rm -rf bridge-slam-engine
# !git clone https://github.com/pshaugh/bridge-slam-engine.git
# %cd bridge-slam-engine
# !pip install -q endplay
# !python slam_engine_benchmark.py
